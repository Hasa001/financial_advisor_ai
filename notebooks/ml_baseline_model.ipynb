# %%
# !pip install pandas numpy scikit-learn lightgbm ta joblib catboost optuna yfinance
# Out:
# Requirement already satisfied: pandas in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (2.1.2)
# Requirement already satisfied: scikit-learn in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: lightgbm in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (4.6.0)
# Requirement already satisfied: ta in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (0.11.0)
# Requirement already satisfied: joblib in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (1.5.2)
# Requirement already satisfied: catboost in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (1.2.8)
# Requirement already satisfied: optuna in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (4.6.0)
# Requirement already satisfied: yfinance in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (0.2.66)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: graphviz in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from catboost) (3.10.6)
# Requirement already satisfied: plotly in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from catboost) (6.5.0)
# Requirement already satisfied: six in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: requests>=2.31 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: Mako in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: pycparser in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: colorama in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\saini\appdata\local\programs\python\python313\lib\site-packages (from plotly->catboost) (2.12.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import glob
import joblib

from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

import ta

# %%
# !py --version
# Out:
# Python 3.13.7

# %%
path = "C:/Users/saini/OneDrive/Desktop/New_Projects/financial-advisor-ai/data"

files = glob.glob(f"{path}/*_data.csv")
print("Detected ML files:", files)

dfs = []

for file in files:
    df_temp = pd.read_csv(file, parse_dates=["date"])
    ticker = file.split("/")[-1].replace("_data.csv", "")
    print(f"Loaded {ticker} with shape:", df_temp.shape)
    df_temp["ticker"] = ticker
    dfs.append(df_temp)

df = pd.concat(dfs, ignore_index=True)
df = df.sort_values(["ticker", "date"]).reset_index(drop=True)
# print("Combined data shape:", df.shape)
# df.head()
# Out:
# Detected ML files: ['C:/Users/saini/OneDrive/Desktop/New_Projects/financial-advisor-ai/data\\BSESN_data.csv', 'C:/Users/saini/OneDrive/Desktop/New_Projects/financial-advisor-ai/data\\NSEBANK_data.csv', 'C:/Users/saini/OneDrive/Desktop/New_Projects/financial-advisor-ai/data\\NSEI_data.csv']
# Loaded data\BSESN with shape: (2629, 19)
# Loaded data\NSEBANK with shape: (2354, 19)
# Loaded data\NSEI with shape: (2630, 19)

# %%
df["ticker_id"] = df["ticker"].astype("category").cat.codes

# %%
# ----- Lag Features -----
for lag in [1, 2, 3, 5]:
    df[f"close_lag_{lag}"] = df["close"].shift(lag)
    df[f"volume_lag_{lag}"] = df["volume"].shift(lag)

# ----- Rolling Stats -----
windows = [3, 5, 7, 10, 14]
for w in windows:
    df[f"roll_mean_{w}"] = df["close"].rolling(w).mean()
    df[f"roll_std_{w}"] = df["close"].rolling(w).std()
    df[f"roll_vol_{w}"] = df["volume"].rolling(w).mean()

# ----- Momentum -----
df["roc_5"] = df["close"].pct_change(5)
df["roc_10"] = df["close"].pct_change(10)
df["momentum"] = df["close"] - df["close"].shift(10)

# ----- ADX -----
df["adx_14"] = ta.trend.ADXIndicator(
    high=df["high"], low=df["low"], close=df["close"], window=14
).adx()

# ----- Weighted Moving Average -----
df["wma_20"] = ta.trend.WMAIndicator(df["close"], window=20).wma()

# Final cleanup
df = df.dropna().reset_index(drop=True)

df.head()
# Out:
#         date         close          high           low          open  volume  \
# 0 2015-04-16  28666.039062  28876.230469  28497.699219  28876.230469    8400
# 1 2015-04-17  28442.099609  28696.189453  28403.759766  28682.970703   13900
# 2 2015-04-20  27886.210938  28539.460938  27802.369141  28525.650391   19000
# 3 2015-04-21  27676.039062  27976.929688  27598.210938  27860.509766   20700
# 4 2015-04-22  27890.130859  27947.259766  27385.480469  27756.679688   11700
#
#    return_1d  return_7d     rsi_14        ema_20  ...  roll_std_10  \
# 0  -0.004641   0.005669  52.057945  28566.496124  ...   325.284160
# 1  -0.007812  -0.002612  47.543091  28554.648837  ...   240.249613
# 2  -0.019545  -0.028617  38.595014  28490.988085  ...   325.281238
# 3  -0.007537  -0.041861  35.847895  28413.373892  ...   445.122284
# 4   0.007736  -0.034255  40.494279  28363.541222  ...   492.014312
#
#    roll_vol_10  roll_mean_14  roll_std_14   roll_vol_14     roc_5    roc_10  \
# 0       9770.0  28373.221540   516.859447  10735.714286 -0.001453  0.024671
# 1      10050.0  28396.812221   511.520761  10485.714286 -0.015340  0.017334
# 2      11140.0  28427.428711   461.346594  10935.714286 -0.034390 -0.013232
# 3      12380.0  28442.957171   428.735979  11600.000000 -0.047114 -0.029063
# 4      12360.0  28436.833705   436.463114  11642.857143 -0.031582 -0.021968
#
#      momentum  adx_14        wma_20
# 0  690.179688     0.0  28481.820964
# 1  484.609375     0.0  28487.410965
# 2 -373.929688     0.0  28441.460528
# 3 -828.421875     0.0  28378.998047
# 4 -626.458984     0.0  28340.704455
#
# [5 rows x 49 columns]

# %%
base_features = [
    "open", "high", "low", "close", "volume",
    "rsi_14", "ema_20", "ema_50",
    "macd", "macd_signal", "macd_hist",
    "bb_high", "bb_mid", "bb_low",
    "return_1d", "return_7d",
    "ticker_id"
]

extra_features = [
    "close_lag_1","close_lag_2","close_lag_3","close_lag_5",
    "volume_lag_1","volume_lag_2","volume_lag_3","volume_lag_5",
    "roll_mean_3","roll_mean_5","roll_mean_7","roll_mean_10","roll_mean_14",
    "roll_std_3","roll_std_5","roll_std_7","roll_std_10","roll_std_14",
    "roll_vol_3","roll_vol_5","roll_vol_7","roll_vol_10","roll_vol_14",
    "roc_5","roc_10","momentum","adx_14","wma_20"
]

feature_cols = base_features + extra_features
target_col = "target_direction"

len(feature_cols)
# Out:
# 45

# %%
train_size = int(len(df) * 0.8)

train_df = df.iloc[:train_size]
valid_df = df.iloc[train_size:]

X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_valid = valid_df[feature_cols]
y_valid = valid_df[target_col]

X_train.shape, X_valid.shape
# Out:
# ((6075, 45), (1519, 45))

# %%
import optuna
from catboost import CatBoostClassifier

def objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 300, 800),
        "depth": trial.suggest_int("depth", 4, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.1),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_seed": 42,
        "loss_function": "Logloss",
        "verbose": False
    }

    model = CatBoostClassifier(**params)
    model.fit(X_train, y_train)

    preds = model.predict_proba(X_valid)[:, 1]
    return roc_auc_score(y_valid, preds)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=25)

print("Best Params:", study.best_params)
# Out:
# [I 2025-11-23 12:25:35,482] A new study created in memory with name: no-name-bafad568-5e9e-4117-b576-a0b985365b04
# [I 2025-11-23 12:26:05,682] Trial 0 finished with value: 0.5559652624575411 and parameters: {'iterations': 406, 'depth': 10, 'learning_rate': 0.04739315002072324, 'l2_leaf_reg': 8.31520521458462}. Best is trial 0 with value: 0.5559652624575411.
# [I 2025-11-23 12:26:09,162] Trial 1 finished with value: 0.5645375914836992 and parameters: {'iterations': 625, 'depth': 6, 'learning_rate': 0.06107550366466079, 'l2_leaf_reg': 6.36356860757198}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:26:16,864] Trial 2 finished with value: 0.5534002171096404 and parameters: {'iterations': 432, 'depth': 8, 'learning_rate': 0.04269470604604354, 'l2_leaf_reg': 5.006461622743483}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:27:07,970] Trial 3 finished with value: 0.5507826452358441 and parameters: {'iterations': 694, 'depth': 10, 'learning_rate': 0.05123677899820828, 'l2_leaf_reg': 3.1973756159553077}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:20,575] Trial 4 finished with value: 0.5641541478446616 and parameters: {'iterations': 795, 'depth': 10, 'learning_rate': 0.038238007859132665, 'l2_leaf_reg': 5.9443296658142}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:25,090] Trial 5 finished with value: 0.5592989459677138 and parameters: {'iterations': 764, 'depth': 5, 'learning_rate': 0.012473891553982024, 'l2_leaf_reg': 5.8714462212915315}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:27,051] Trial 6 finished with value: 0.5559407500787898 and parameters: {'iterations': 533, 'depth': 4, 'learning_rate': 0.045259872305303706, 'l2_leaf_reg': 7.040960200285417}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:31,573] Trial 7 finished with value: 0.5502591308610848 and parameters: {'iterations': 417, 'depth': 7, 'learning_rate': 0.01715288428010322, 'l2_leaf_reg': 6.710571005718801}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:33,185] Trial 8 finished with value: 0.547683580208005 and parameters: {'iterations': 426, 'depth': 4, 'learning_rate': 0.08327484949362607, 'l2_leaf_reg': 2.1262092484992814}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:50,936] Trial 9 finished with value: 0.5613107119095143 and parameters: {'iterations': 795, 'depth': 8, 'learning_rate': 0.0365944163200012, 'l2_leaf_reg': 4.193790653723822}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:28:56,684] Trial 10 finished with value: 0.5544052246384424 and parameters: {'iterations': 614, 'depth': 6, 'learning_rate': 0.07666698617443517, 'l2_leaf_reg': 9.370719280871842}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:29:12,260] Trial 11 finished with value: 0.558649367930805 and parameters: {'iterations': 637, 'depth': 8, 'learning_rate': 0.06640487033374157, 'l2_leaf_reg': 7.659054372961997}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:29:17,102] Trial 12 finished with value: 0.5574482613719929 and parameters: {'iterations': 540, 'depth': 6, 'learning_rate': 0.09691642556495156, 'l2_leaf_reg': 5.37624407679329}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:29:42,846] Trial 13 finished with value: 0.5448121301257134 and parameters: {'iterations': 712, 'depth': 9, 'learning_rate': 0.027670083400178985, 'l2_leaf_reg': 4.091913894626277}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:29:46,834] Trial 14 finished with value: 0.5599030010155128 and parameters: {'iterations': 610, 'depth': 6, 'learning_rate': 0.06219239409448293, 'l2_leaf_reg': 9.99544697966899}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:29:50,200] Trial 15 finished with value: 0.5455877718247715 and parameters: {'iterations': 301, 'depth': 7, 'learning_rate': 0.0297614994912938, 'l2_leaf_reg': 8.49933563083806}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:30:26,778] Trial 16 finished with value: 0.5589137514444795 and parameters: {'iterations': 717, 'depth': 9, 'learning_rate': 0.061958861266393356, 'l2_leaf_reg': 6.280138720855737}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:30:33,844] Trial 17 finished with value: 0.5543246839654026 and parameters: {'iterations': 660, 'depth': 5, 'learning_rate': 0.07921383292099665, 'l2_leaf_reg': 1.915546284287096}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:31:02,344] Trial 18 finished with value: 0.5408901495255104 and parameters: {'iterations': 573, 'depth': 9, 'learning_rate': 0.02308807525987829, 'l2_leaf_reg': 4.806675589679309}. Best is trial 1 with value: 0.5645375914836992.
# [I 2025-11-23 12:31:05,366] Trial 19 finished with value: 0.5698077529152221 and parameters: {'iterations': 498, 'depth': 5, 'learning_rate': 0.0051554802299490915, 'l2_leaf_reg': 7.402031326036212}. Best is trial 19 with value: 0.5698077529152221.
# [I 2025-11-23 12:31:08,760] Trial 20 finished with value: 0.5695976468116398 and parameters: {'iterations': 496, 'depth': 5, 'learning_rate': 0.007582151503505406, 'l2_leaf_reg': 7.585045426746653}. Best is trial 19 with value: 0.5698077529152221.
# [I 2025-11-23 12:31:11,560] Trial 21 finished with value: 0.5728525405329692 and parameters: {'iterations': 475, 'depth': 5, 'learning_rate': 0.006838567935993817, 'l2_leaf_reg': 7.473365536756501}. Best is trial 21 with value: 0.5728525405329692.
# [I 2025-11-23 12:31:14,401] Trial 22 finished with value: 0.5752757642609518 and parameters: {'iterations': 484, 'depth': 5, 'learning_rate': 0.005485385655706523, 'l2_leaf_reg': 7.730469418956361}. Best is trial 22 with value: 0.5752757642609518.
# [I 2025-11-23 12:31:16,914] Trial 23 finished with value: 0.5790436670518612 and parameters: {'iterations': 481, 'depth': 4, 'learning_rate': 0.005289895921602941, 'l2_leaf_reg': 8.424221303047148}. Best is trial 23 with value: 0.5790436670518612.
# [I 2025-11-23 12:31:18,666] Trial 24 finished with value: 0.5809626361312463 and parameters: {'iterations': 358, 'depth': 4, 'learning_rate': 0.017929661695989953, 'l2_leaf_reg': 8.982509829711734}. Best is trial 24 with value: 0.5809626361312463.
# Best Params: {'iterations': 358, 'depth': 4, 'learning_rate': 0.017929661695989953, 'l2_leaf_reg': 8.982509829711734}

# %%
best_params = study.best_params
best_params["loss_function"] = "Logloss"
best_params["verbose"] = False

from catboost import CatBoostClassifier

model = CatBoostClassifier(**best_params)
model.fit(X_train, y_train)

print("Final model trained with Optuna parameters!")
# Out:
# Final model trained with Optuna parameters!

# %%
y_pred = model.predict(X_valid)
y_proba = model.predict_proba(X_valid)[:, 1]

print("Accuracy:", accuracy_score(y_valid, y_pred))
print("ROC-AUC:", roc_auc_score(y_valid, y_proba))
print(classification_report(y_valid, y_pred))
# Out:
# Accuracy: 0.5569453587886768
# ROC-AUC: 0.5693140035718037
#               precision    recall  f1-score   support
#
#            0       0.51      0.36      0.42       684
#            1       0.58      0.72      0.64       835
#
#     accuracy                           0.56      1519
#    macro avg       0.54      0.54      0.53      1519
# weighted avg       0.55      0.56      0.54      1519

# %%
joblib.dump(model, "C:/Users/saini/OneDrive/Desktop/New_Projects/financial-advisor-ai/ml/upgraded_catboost_model.pkl")
print("Model saved as upgraded_catboost_model.pkl")
# Out:
# Model saved as upgraded_catboost_model.pkl

# %%
def predict_next_day(input_row):
    data = input_row[feature_cols].values.reshape(1, -1)
    direction = int(model.predict(data)[0])
    confidence = float(model.predict_proba(data)[0][1])
    
    return {
        "direction": direction,
        "confidence": confidence
    }

# Test on last record
predict_next_day(df.iloc[-1])
# Out:
# {'direction': 1, 'confidence': 0.527952961627416}
